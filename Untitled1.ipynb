# %%
import os
os.chdir("/Users/burke/Documents/research/bpCog/microsim")
from microsim.population import NHANESDirectSamplePopulation

pop = NHANESDirectSamplePopulation(n=10000, year=1999)
pop.advance_vectorized(2)
# Out:
# processing year: 0
# processing year: 1
# (       age  baseAge  populationIndex  gender  raceEthnicity  black  \
#  0     53.0     51.0                0       2              2  False
#  1     37.0     35.0                1       1              3  False
#  2     35.0     33.0                2       2              3  False
#  3     37.0     35.0                3       1              3  False
#  4     50.0     48.0                4       2              3  False
#  ...    ...      ...              ...     ...            ...    ...
#  9995  62.0     60.0             9995       1              3  False
#  9996  49.0     47.0             9996       2              5  False
#  9997  21.0     19.0             9997       1              4   True
#  9998  61.0     59.0             9998       1              3  False
#  9999  68.0     66.0             9999       2              2  False
#
#               sbp        dbp       a1c  current_diabetes  ...       bmi2  \
# ...
